# %% [markdown]
# <a href="https://colab.research.google.com/github/Miablo/decay-before-archival/blob/main/OS_Project_Health_Signals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.cloud import bigquery' then 'client = bigquery.Client(project="your-gcp-project-id")
