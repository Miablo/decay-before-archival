# %% [markdown]
# # PyPI download stats

# %% [markdown]
# _Part of the **Decay Before Archival** project — see `README.md` for full project context, setup instructions, and links to the other notebooks (`deps_dev.ipynb`, `scorecard.ipynb`, `gh_archive.ipynb`, `pypi.ipynb`, `other_sources.ipynb`)._

# %%
from google.cloud import bigquery
from decay_before_archival import get_client

client = get_client()

# %% [markdown]
# ## Explore: PyPI download stats
#
# This dataset's tables can be huge — always scope by date and keep the `LIMIT` while exploring.
#
# **Planned analysis:** trailing download volume as a popularity control, so a drop in maintenance signals isn't confused with a project that was simply never popular.

# %%
# TODO: list tables in the bigquery-public-data.pypi dataset (INFORMATION_SCHEMA.TABLES, same pattern as deps.dev above).

# %% [markdown]
# **Notes:**
#
# _(add observations here)_

# %%
# TODO: peek the columns of whichever table looks most relevant (INFORMATION_SCHEMA.COLUMNS).

# %% [markdown]
# **Notes:**
#
# _(add observations here)_

# %%
# TODO: pull a small, date-scoped LIMITed sample from that table (dry-run first — these tables can be huge).

# %% [markdown]
# **Notes:**
#
# _(add observations here)_
