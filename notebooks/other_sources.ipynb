# %% [markdown]
# # Other data sources (OSV.dev, GitHub API, npm downloads, CHAOSS)

# %% [markdown]
# _Part of the **Decay Before Archival** project — see `README.md` for full project context, setup instructions, and links to the other notebooks (`deps_dev.ipynb`, `scorecard.ipynb`, `gh_archive.ipynb`, `pypi.ipynb`, `other_sources.ipynb`)._

# %% [markdown]
# **Before you start:** if you pick one of the sources below to explore, create your own notebook for it (following the pattern of `deps_dev.ipynb`, `scorecard.ipynb`, etc. — intro, `bq_client` setup, list → peek columns → sample) instead of adding cells here. This file is just a holding area for sources nobody has claimed yet.
#
# Also keep in mind: we will eventually need to **integrate/merge all of our datasets** (deps.dev, Scorecard, GH Archive, PyPI, and whatever you pick from here) into one combined dataset. So as you explore a new source, note what you could join it on back to the others (e.g. project name, repo owner+name, or package name) — that join key is what integration will depend on later.

# %%
from google.cloud import bigquery
from decay_before_archival import get_client

client = get_client()

# %% [markdown]
# ## Explore: OSV.dev (TODO)
#
# OSV.dev aggregates GitHub Security Advisories, PyPI, npm, Go, RubyGems, Maven, Cargo, and distro advisory feeds into one schema with affected package/version ranges and publish/modify dates.
#
# **Planned analysis:** advisory volume and staleness (time since last modified) as a proxy for whether a project is still triaging security issues.

# %%
# TODO: figure out how to query OSV.dev (REST API, or a public dataset mirror if one exists) and pull a small sample of advisories.

# %% [markdown]
# **Notes:**
#
# _(add observations here)_

# %% [markdown]
# ## Explore: GitHub REST/GraphQL API (TODO)
#
# Fills gaps GH Archive/Scorecard don't cover directly — live issue/PR state, contributor lists, bus-factor calculations.
#
# **Planned analysis:** current open issue/PR counts and per-contributor commit share, to compute bus factor (impact of losing a top maintainer) directly rather than inferring it from event history.

# %%
# TODO: explore the GitHub REST/GraphQL API for one sample project — issue/PR counts, contributor list, etc.

# %% [markdown]
# **Notes:**
#
# _(add observations here)_

# %% [markdown]
# ## Explore: npm downloads API (TODO)
#
# npm's download-counts API, as the npm-side counterpart to the PyPI download stats above.
#
# **Planned analysis:** same role as PyPI download stats — a popularity control for npm-ecosystem packages.

# %%
# TODO: explore npm's download-counts API for one sample package and pull a small sample response.

# %% [markdown]
# **Notes:**
#
# _(add observations here)_

# %% [markdown]
# ## Explore: CHAOSS Metrics (TODO)
#
# CHAOSS provides standardized definitions/calculations for community health metrics (e.g. contributor absence factor, time-to-first-response).
#
# **Planned analysis:** cross-check our own derived metrics against CHAOSS's standard definitions, and borrow any calculation we haven't already covered via GH Archive/the GitHub API.

# %%
# TODO: look up CHAOSS's metric definitions and note which ones we can compute from data we already have.

# %% [markdown]
# **Notes:**
#
# _(add observations here)_
